# %% [markdown]
# # Box Plots Activity 1

# %% [markdown]
# ## Import libraries
#
# First thing you need to do is import `pandas` below.

# %% [markdown]
# Next, import `plotly express` below

# %% [markdown]
# ## Load data
#
# This time let's work on a dataset with information about different candies.
#
# Load the CSV file `"datasets/candy-data.csv"` into a dataframe and display it.

# %% [markdown]
# ## Create a Box Plot
#
# Now, create box plot that shows the distribution of `sugarpercent` for unique values of `chocolate`. The `chocolate` column has values of `0` and `1` for chocolate vs non-chocolate candies.

# %% [markdown]
# **QUESTION:**
#
# What is the independent variable for this case?
#
# Write your answer in the cell below.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <!-- YOUR ANSWER BEGIN -->
#
#
#
#
#
# <!-- YOUR ANSWER END -->
# </div>

# %% [markdown]
# **QUESTION:**
#
# What is the dependent variable for this case?
#
# Write your answer in the cell below.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <!-- YOUR ANSWER BEGIN -->
#
#
#
#
#
# <!-- YOUR ANSWER END -->
# </div>

# %% [markdown]
# **QUESTION:**
#
# To generate a box plot with vertical orientation, which column should be on the x-axis and which column should be on the y-axis?
#
# Write your answer in the cell below.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <!-- YOUR ANSWER BEGIN -->
#
#
#
#
#
# <!-- YOUR ANSWER END -->
# </div>

# %% [markdown]
# Generate the box plot using your answers to the previous questions.

# %% [markdown]
# **QUESTION:**
#
# Describe the box plots with respect to the median values, lower quartile, upper quartile, and size of the interquartile range.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <!-- YOUR ANSWER BEGIN -->
#
#
#
#
#
# <!-- YOUR ANSWER END -->
# </div>

# %% [markdown]
# **QUESTION:**
#
# What is the range of this box plot?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <!-- YOUR ANSWER BEGIN -->
#
#
#
#
#
# <!-- YOUR ANSWER END -->
# </div>
